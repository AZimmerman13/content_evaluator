# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_json('../data/train.jsonl', lines=True)

# %%
df.head()
# Out:
#       id            img  label  \
# 0  42953  img/42953.png      0
# 1  23058  img/23058.png      0
# 2  13894  img/13894.png      0
# 3  37408  img/37408.png      0
# 4  82403  img/82403.png      0
#
#                                                 text
# 0   its their character not their color that matters
# 1  don't be afraid to love again everyone is not ...
# 2                           putting bows on your pet
# 3  i love everything and everybody! except for sq...
# 4  everybody loves chocolate chip cookies, even h...

# %%
data = df.sample(20, random_state=13).reset_index(drop=True)

# %%
img_names = data.img.tolist()

# %%
print(img_names)
# Out:
# ['img/10792.png', 'img/62458.png', 'img/23415.png', 'img/37052.png', 'img/02538.png', 'img/37180.png', 'img/02945.png', 'img/63150.png', 'img/83504.png', 'img/48051.png', 'img/71925.png', 'img/58246.png', 'img/20876.png', 'img/36054.png', 'img/75618.png', 'img/38416.png', 'img/27351.png', 'img/56091.png', 'img/39420.png', 'img/89152.png']

# %%
from skimage.io import imread
from skimage import io, color, filters, restoration, feature
from skimage.transform import resize, rotate

# %%
img = imread('../data/img/10792.png')

# %%
io.imshow(resize(img, (100,100,3)));

# %%
io.imshow(img);

# %%
data.head()
# Out:
#       id            img  label  \
# 0  10792  img/10792.png      0
# 1  62458  img/62458.png      0
# 2  23415  img/23415.png      0
# 3  37052  img/37052.png      1
# 4   2538  img/02538.png      0
#
#                                                 text
# 0            guys what the fuck what the actual fuck
# 1                                  happy and in love
# 2  your purchase of $19.99 comes to $21.36 after ...
# 3  oh boy can't wait to clean myself up in the 90...
# 4  when my girl pissed me off but she runs throug...

# %%
io.imshow('../data/'+img_names[3]);

# %%
io.imshow('../data/'+img_names[18]);

# %%
print(data.label)
# Out:
# 0     0
# 1     0
# 2     0
# 3     1
# 4     0
# 5     1
# 6     1
# 7     0
# 8     1
# 9     1
# 10    0
# 11    1
# 12    0
# 13    0
# 14    0
# 15    0
# 16    0
# 17    1
# 18    1
# 19    0
# Name: label, dtype: int64

# %%
print(data.text[18])
# Out:
# getting stoned in america can be expensive in islamic country, say you're gay and get stoned for free [dark humour] so progressive
